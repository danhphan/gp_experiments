# %% [markdown]
# ## Re-run Modeling spawning salmon with PyMC v4
# Source: https://github.com/fonnesbeck/gp_regression/blob/master/notebooks/spawning_salmon.ipynb

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pymc as pm
import aesara as ae
import arviz as az
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore')

# %%
salmon_data = pd.read_table('../data/test_gp.csv', delimiter=',')

# %%
salmon_data.rename(columns={'Price':'recruits'}, inplace=True)
salmon_data['spawners'] = salmon_data.index

# %%
salmon_data.plot.scatter(x='spawners', y='recruits', s=50);

# %%
x, y = salmon_data[['spawners', 'recruits']].values.T

# %%
x.max(), x.min(), x.max() - x.min()
# Out:
# (51.0, 0.0, 51.0)

# %%
y.max(), y.min(), y.max() - y.min()
# Out:
# (85.29799999999999, 51.03, 34.26799999999999)

# %% [markdown]
# ### Gaussian Process

# %%
# %%time
with pm.Model() as gp_model:
    c = pm.HalfCauchy('c', 5)
    eta = pm.HalfCauchy('eta', 1)
    
    K = eta * pm.gp.cov.Linear(input_dim=1, c=c)
    
    σ = pm.HalfNormal('σ', 50)
    
    recruit_gp = pm.gp.Marginal(cov_func=K)
    recruit_gp.marginal_likelihood('recruits', X=salmon_data.spawners.values.reshape(-1,1), 
                           y=salmon_data.recruits.values.reshape(-1,1), noise=σ)
# Out:
# CPU times: user 134 ms, sys: 6.14 ms, total: 140 ms
# Wall time: 138 ms

# %%
# %%time
with gp_salmon_model:
    gp_trace = pm.sample(1000, tune=2000, cores=2, random_seed=42)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [ρ, η, σ]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='419' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.98% [419/6000 00:44<09:47 Sampling 2 chains, 0 divergences]
#     </div>
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 129, in run
#     self._start_loop()
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 182, in _start_loop
#     point, stats = self._compute_point()
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 207, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/arraystep.py", line 286, in step
#     return super().step(point)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/arraystep.py", line 208, in step
#     step_res = self.astep(q)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/hmc/base_hmc.py", line 165, in astep
#     self.potential.raise_ok(q0.point_map_info)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/hmc/quadpotential.py", line 308, in raise_ok
#     raise ValueError("\n".join(errmsg))
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `ρ_log__`.ravel()[[0]] is zero.
# The derivative of RV `η_log__`.ravel()[[0]] is zero.
# The derivative of RV `σ_log__`.ravel()[[]] is zero.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `ρ_log__`.ravel()[[0]] is zero.
# The derivative of RV `η_log__`.ravel()[[0]] is zero.
# The derivative of RV `σ_log__`.ravel()[[]] is zero.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File ~/WORK/codes/oss/pymc/pymc/sampling.py:607, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, **kwargs)
#     605 _print_step_hierarchy(step)
#     606 try:
# --> 607     mtrace = _mp_sample(**sample_args, **parallel_args)
#     608 except pickle.PickleError:
#     609     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/WORK/codes/oss/pymc/pymc/sampling.py:1535, in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, **kwargs)
#    1533 try:
#    1534     with sampler:
# -> 1535         for draw in sampler:
#    1536             strace = traces[draw.chain - chain]
#    1537             if strace.supports_sampler_stats and draw.stats is not None:
#
# File ~/WORK/codes/oss/pymc/pymc/parallel_sampling.py:464, in ParallelSampler.__iter__(self)
#     461     self._progress.update(self._total_draws)
#     463 while self._active:
# --> 464     draw = ProcessAdapter.recv_draw(self._active)
#     465     proc, is_last, draw, tuning, stats, warns = draw
#     466     self._total_draws += 1
#
# File ~/WORK/codes/oss/pymc/pymc/parallel_sampling.py:353, in ProcessAdapter.recv_draw(processes, timeout)
#     351     else:
#     352         error = RuntimeError("Chain %s failed." % proc.chain)
# --> 353     raise error from old_error
#     354 elif msg[0] == "writing_done":
#     355     proc._readable = True
#
# RuntimeError: Chain 0 failed.

# %%
with pm.Model() as gp_salmon_model:

    # Lengthscale
    ρ = pm.HalfCauchy('ρ', 5)
    η = pm.HalfCauchy('η', 5)
#     ρ = pm.Gamma('ρ', 5, 0.1)
#     η = pm.Gamma('η', 5, 0.1)
    
    M = pm.gp.mean.Linear(coeffs=(salmon_data.recruits/salmon_data.spawners).mean())
    K = (η**2) * pm.gp.cov.ExpQuad(1, ρ) 
    
    σ = pm.HalfNormal('σ', 50)
    
    recruit_gp = pm.gp.Marginal(cov_func=K)
    recruit_gp.marginal_likelihood('recruits', X=salmon_data.spawners.values.reshape(-1,1), 
                           y=salmon_data.recruits.values.reshape(-1,1), noise=σ)

# %%
salmon_data.recruits.values.shape, salmon_data.spawners.values.reshape(-1,1).shape
# Out:
# ((52,), (52, 1))

# %% [markdown]
# #### Using trace

# %%
# %%time
with gp_salmon_model:
    gp_trace = pm.sample(1000, tune=2000, cores=2, random_seed=42)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [ρ, η, σ]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='419' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.98% [419/6000 00:43<09:35 Sampling 2 chains, 0 divergences]
#     </div>
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 129, in run
#     self._start_loop()
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 182, in _start_loop
#     point, stats = self._compute_point()
#   File "/home/danh/WORK/codes/oss/pymc/pymc/parallel_sampling.py", line 207, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/arraystep.py", line 286, in step
#     return super().step(point)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/arraystep.py", line 208, in step
#     step_res = self.astep(q)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/hmc/base_hmc.py", line 165, in astep
#     self.potential.raise_ok(q0.point_map_info)
#   File "/home/danh/WORK/codes/oss/pymc/pymc/step_methods/hmc/quadpotential.py", line 308, in raise_ok
#     raise ValueError("\n".join(errmsg))
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `ρ_log__`.ravel()[[0]] is zero.
# The derivative of RV `η_log__`.ravel()[[0]] is zero.
# The derivative of RV `σ_log__`.ravel()[[]] is zero.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `ρ_log__`.ravel()[[0]] is zero.
# The derivative of RV `η_log__`.ravel()[[0]] is zero.
# The derivative of RV `σ_log__`.ravel()[[]] is zero.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File ~/WORK/codes/oss/pymc/pymc/sampling.py:607, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, **kwargs)
#     605 _print_step_hierarchy(step)
#     606 try:
# --> 607     mtrace = _mp_sample(**sample_args, **parallel_args)
#     608 except pickle.PickleError:
#     609     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/WORK/codes/oss/pymc/pymc/sampling.py:1535, in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, **kwargs)
#    1533 try:
#    1534     with sampler:
# -> 1535         for draw in sampler:
#    1536             strace = traces[draw.chain - chain]
#    1537             if strace.supports_sampler_stats and draw.stats is not None:
#
# File ~/WORK/codes/oss/pymc/pymc/parallel_sampling.py:464, in ParallelSampler.__iter__(self)
#     461     self._progress.update(self._total_draws)
#     463 while self._active:
# --> 464     draw = ProcessAdapter.recv_draw(self._active)
#     465     proc, is_last, draw, tuning, stats, warns = draw
#     466     self._total_draws += 1
#
# File ~/WORK/codes/oss/pymc/pymc/parallel_sampling.py:353, in ProcessAdapter.recv_draw(processes, timeout)
#     351     else:
#     352         error = RuntimeError("Chain %s failed." % proc.chain)
# --> 353     raise error from old_error
#     354 elif msg[0] == "writing_done":
#     355     proc._readable = True
#
# RuntimeError: Chain 0 failed.

# %%
az.plot_trace(gp_trace, var_names=['ρ', 'η', 'σ']);

# %%
X_pred = np.linspace(-5, 55, 60)
with gp_salmon_model:
    salmon_pred = recruit_gp.conditional("salmon_pred", X_pred.reshape(-1, 1))
    gp_salmon_samples = pm.sample_posterior_predictive(gp_trace, var_names=['salmon_pred'], 
                                                       random_seed=42)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>

# %%
# Plot posterior predictive with X_pred using trace
from pymc.gp.util import plot_gp_dist
fig, ax = plt.subplots(figsize=(8,6))
plot_gp_dist(ax, gp_salmon_samples.posterior_predictive['salmon_pred'].sel(chain=1), X_pred)
salmon_data.plot.scatter(x='spawners', y='recruits', c='k', s=50, ax=ax)
ax.set_ylim(0, 100);
plt.title("Posterior predictive using trace");

# %% [markdown]
# #### Using find MAP

# %%
with gp_salmon_model:
    mp = pm.find_MAP()
    salmon_pred_map = recruit_gp.conditional("salmon_pred_map", X_pred.reshape(-1, 1))
    salmon_samples = pm.sample_posterior_predictive([mp], samples=1000, 
                                                    var_names=['salmon_pred_map'], keep_size=False)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='21' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00 logp = -446.05, ||grad|| = 150.65]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:03<00:00]
#     </div>

# %%
# THIS SEEMS WRONG!!!
from pymc.gp.util import plot_gp_dist
fig, ax = plt.subplots(figsize=(8,6))
plot_gp_dist(ax, salmon_samples.posterior_predictive['salmon_pred_map'].sel(chain=0), X_pred)
salmon_data.plot.scatter(x='spawners', y='recruits', c='k', s=50, ax=ax)
ax.set_ylim(0, 350)
plt.title("Posterior predictive using find MAP");

# %%
mp_log = {k: v for k, v in mp.item}
# Out:
# {'ρ_log__': array(1.60943791),
#  'η_log__': array(1.60943791),
#  'σ_log__': array(3.91202301),
#  'salmon_pred': array([5.23321029e-24, 4.26462020e+00, 8.52924040e+00, 1.27938606e+01,
#         1.70584808e+01, 2.13231014e+01, 2.55877632e+01, 2.98541057e+01,
#         3.41452975e+01, 3.85628976e+01, 4.31390661e+01, 4.75491260e+01,
#         5.16589097e+01, 5.56731219e+01, 5.97614014e+01, 6.39749024e+01,
#         6.82341651e+01, 7.25001045e+01, 7.67875729e+01, 8.11663545e+01,
#         8.55912470e+01, 8.99055048e+01, 9.42826203e+01, 9.85248547e+01,
#         1.02525325e+02, 1.06657671e+02, 1.10988576e+02, 1.15415093e+02,
#         1.19697871e+02, 1.23826140e+02, 1.28004626e+02, 1.32340659e+02,
#         1.36709740e+02, 1.40917741e+02, 1.45157486e+02, 1.49490101e+02,
#         1.53829440e+02, 1.58108664e+02, 1.62208568e+02, 1.66348409e+02,
#         1.70598006e+02, 1.74926406e+02, 1.79301645e+02, 1.83548962e+02,
#         1.87737250e+02, 1.92038567e+02, 1.96355982e+02, 2.00575683e+02,
#         2.04741778e+02, 2.08907798e+02, 2.13021417e+02, 2.17296755e+02,
#         2.21789728e+02, 2.26035178e+02, 2.30079995e+02, 2.34106232e+02,
#         2.38203816e+02, 2.42513179e+02, 2.46952489e+02, 2.51253671e+02,
#         2.55448895e+02, 2.59670276e+02, 2.64031712e+02, 2.68569164e+02,
#         2.72954403e+02, 2.77210411e+02, 2.81464556e+02, 2.85699067e+02,
#         2.89759767e+02, 2.93609466e+02, 2.97863045e+02, 3.02412520e+02,
#         3.06449181e+02, 3.10484513e+02, 3.15137736e+02, 3.19636209e+02,
#         3.23498478e+02, 3.27340927e+02, 3.31991025e+02, 3.36635651e+02,
#         3.40696928e+02, 3.44650539e+02, 3.48772660e+02, 3.52804384e+02,
#         3.56396296e+02, 3.60216182e+02, 3.65399313e+02, 3.70077115e+02,
#         3.73722657e+02, 3.78246883e+02, 3.83403404e+02, 3.88030344e+02,
#         3.92306963e+02, 3.96288715e+02, 3.99831195e+02, 4.03774631e+02,
#         4.08097814e+02, 4.12220373e+02, 4.17087479e+02, 4.22011493e+02]),
#  'ρ': array(5.),
#  'η': array(5.),
#  'σ': array(50.)}

# %%
mp_log = {k: v for k, v in mp.items() if "log" in k or "pred" in k}
mp_log
# Out:
# {'ρ_log__': array(1.60943791),
#  'η_log__': array(1.60943791),
#  'σ_log__': array(3.91202301),
#  'salmon_pred': array([5.23321029e-24, 4.26462020e+00, 8.52924040e+00, 1.27938606e+01,
#         1.70584808e+01, 2.13231014e+01, 2.55877632e+01, 2.98541057e+01,
#         3.41452975e+01, 3.85628976e+01, 4.31390661e+01, 4.75491260e+01,
#         5.16589097e+01, 5.56731219e+01, 5.97614014e+01, 6.39749024e+01,
#         6.82341651e+01, 7.25001045e+01, 7.67875729e+01, 8.11663545e+01,
#         8.55912470e+01, 8.99055048e+01, 9.42826203e+01, 9.85248547e+01,
#         1.02525325e+02, 1.06657671e+02, 1.10988576e+02, 1.15415093e+02,
#         1.19697871e+02, 1.23826140e+02, 1.28004626e+02, 1.32340659e+02,
#         1.36709740e+02, 1.40917741e+02, 1.45157486e+02, 1.49490101e+02,
#         1.53829440e+02, 1.58108664e+02, 1.62208568e+02, 1.66348409e+02,
#         1.70598006e+02, 1.74926406e+02, 1.79301645e+02, 1.83548962e+02,
#         1.87737250e+02, 1.92038567e+02, 1.96355982e+02, 2.00575683e+02,
#         2.04741778e+02, 2.08907798e+02, 2.13021417e+02, 2.17296755e+02,
#         2.21789728e+02, 2.26035178e+02, 2.30079995e+02, 2.34106232e+02,
#         2.38203816e+02, 2.42513179e+02, 2.46952489e+02, 2.51253671e+02,
#         2.55448895e+02, 2.59670276e+02, 2.64031712e+02, 2.68569164e+02,
#         2.72954403e+02, 2.77210411e+02, 2.81464556e+02, 2.85699067e+02,
#         2.89759767e+02, 2.93609466e+02, 2.97863045e+02, 3.02412520e+02,
#         3.06449181e+02, 3.10484513e+02, 3.15137736e+02, 3.19636209e+02,
#         3.23498478e+02, 3.27340927e+02, 3.31991025e+02, 3.36635651e+02,
#         3.40696928e+02, 3.44650539e+02, 3.48772660e+02, 3.52804384e+02,
#         3.56396296e+02, 3.60216182e+02, 3.65399313e+02, 3.70077115e+02,
#         3.73722657e+02, 3.78246883e+02, 3.83403404e+02, 3.88030344e+02,
#         3.92306963e+02, 3.96288715e+02, 3.99831195e+02, 4.03774631e+02,
#         4.08097814e+02, 4.12220373e+02, 4.17087479e+02, 4.22011493e+02])}

# %%
print(gp_salmon_model.compile_logp(jacobian=False))
# Out:
# <pymc.model.PointFunc object at 0x7f90d5f1a760>

# %%
gp_salmon_model.compile_logp(jacobian=False)(mp_log)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 gp_salmon_model.compile_logp(jacobian=False)(mp_log)
#
# File ~/WORK/codes/oss/pymc/pymc/model.py:1806, in PointFunc.__call__(self, state)
#    1805 def __call__(self, state):
# -> 1806     return self.f(**state)
#
# File ~/miniconda3/envs/pymc-dev-py39/lib/python3.9/site-packages/aesara/compile/function/types.py:946, in Function.__call__(self, *args, **kwargs)
#     944 if c.required and not c.provided:
#     945     restore_defaults()
# --> 946     raise TypeError(
#     947         f"Missing required input: {getattr(self.inv_finder[c], 'variable', self.inv_finder[c])}"
#     948     )
#     949 if c.provided > 1:
#     950     restore_defaults()
#
# TypeError: Missing required input: salmon_pred_map

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Sat Jun 04 2022
#
# Python implementation: CPython
# Python version       : 3.9.12
# IPython version      : 8.3.0
#
# numpy     : 1.22.4
# pymc      : 4.0.0b6
# aesara    : 2.6.2
# matplotlib: 3.5.2
# pandas    : 1.4.2
# arviz     : 0.12.1
#
# Watermark: 2.3.0
